# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup, Comment
from tqdm.notebook import tqdm
from pathlib import Path
import warnings

# %%
resp = requests.get('https://www.pro-football-reference.com/boxscores/199509030atl.htm')

# %%
def extract_comments(response, css_selectors):
    if isinstance(response, requests.models.Response):
        soup = BeautifulSoup(response.text, 'lxml')
    if isinstance(response, str):
        soup = BeautifulSoup(response, 'lxml')
    if isinstance(response, BeautifulSoup):
        warnings.warn('Calling this function modifies the BeautifulSoup object by extracting the comment from the DOM')
        soup = response
    for element in soup(text=lambda text: isinstance(text, Comment)):
        comment = element.extract()
        ret = BeautifulSoup(comment).find('div')
        if ret:
            ret = ret.find('table', css_selectors)
            if ret:
                return ret
    return comments

# %%
def get_pdr_id(url):
    return url.split('/')[-1].split('.htm')[0]

# %%
table = extract_comments(resp, {'id':'pbp'})

# %%
# Get the fancy table headers hidden in the mouseover 
header_row = table.find('tr')
headers = [header['aria-label'] for header in header_row.find_all('th')]

# %%
table.find_all('tr')[2].find_all('td')[3].text.split(' ')[0]
# Out:
# 'CAR'

# %%
plays = list()
# STarting at drive 1
drive = 1
score = False
play_number = 1  # Techinically don't need this cuz the index for the DF will have it; but we don't have a DF yet =]
# This is the hackiest of all hacks; basically figure out who kicked out based on where the ball is marked
pos_team = f"Not {table.find_all('tr')[2].find_all('td')[3].text.split(' ')[0]}"
other_team = table.find_all('tr')[2].find_all('td')[3].text.split(' ')[0]

for row in table.find_all('tr')[1:]:
    header_class = row.get('class')
    if header_class:
        # These are useless rows
        if 'thead' in header_class:
            continue
        # They bold between drives, so increment if we see one (this may break for kickoffs after touchdowns?)
        if 'divider' in header_class:
            drive = drive + 1
            
            # We can use these dividers to deal with posession.  This will likely break if possession changes multiple times in one play
            
        # If we score, yay!
        if 'score' in header_class:
            score = True
        else:
            score = False
    # Add all the "stock" information from the table to a dict, using the headers we defined before
    play.update(dict(zip(headers, [col.text for col in row.find_all(['th', 'td'])])))
    # Add some of our own inferred information
    play['drive'] = drive
    play['score'] = score
    play['play_number'] = play_number
    # Now for the hard part; let's start parsing the description field
    desc = row.find_all('td')[4]
    
    # Let's extract the action players
    action_players = [entity for entity in desc.find_all('a') if entity.text]
    ret_action_players = list()
    
    # We're gonna add a row that's a list of dicts for the action player (which is dumb to do in a dataframe, but whatever)
    # Each element in the list is a dictionary of: 'name': 'A', 'pfr_id': 'B'
    for player in action_players:
        ret_action_player = dict()
        ret_action_player['name'] = player.text
        ret_action_player['pfr_id'] = get_pdr_id(player['href'])
        ret_action_players.append(ret_action_player)
        
    play['action_players'] = ret_action_players
    
    # Passes
    print(f"Play {play['play_number']} on drive {play['drive']}, ", end='')
    if 'pass complete' in desc.text:
        print(f"Complete pass by {play['action_players'][0]}")
        # We can't guarantee there'll be an action reciever
        try:
            # There may be cases where the second action player is a tackler, etc.
            print(f"\t to {play['action_players'][1]}")
        except IndexError:
              pass
    elif 'pass incomplete' in desc.text:
        print(f"Incomplete pass by {play['action_players'][0]}")
    # Rushes
    elif 'middle' in desc.text or 'right' in desc.text or 'left' in desc.text:
        print(f"Rush by {play['action_players'][0]}")
    # Penalty
    elif 'Penalty' in desc.text:
        print(f"Penalty by {play['action_players'][0]}")
    # Sacked
    elif 'Sacked' in desc.text:
        print(f"Penalty by {play['action_players'][0]} sacked by {play['action_players'][1]} ")
    # Kickoff
    elif 'kicks off' in desc.text:
        print(f"Kickoff by {play['action_players'][0]}")
        if not 'touchback' in desc.text:
            print(f"\treturn by {play['action_players'][1]}")
        else:
            print(f"\ttouchback")
        
    
    # Etc. etc.

    
    plays.append(play)
    play_number = play_number + 1
# Out:
# Play 1 on drive 1, Kickoff by {'name': 'John Kasay', 'pfr_id': 'kasayjoh01'}
# 	return by {'name': 'Roell Preston', 'pfr_id': 'PresRo00'}
# Play 2 on drive 1, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 3 on drive 1, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Steve Lofton', 'pfr_id': 'LoftSt20'}
# Play 4 on drive 1, Incomplete pass by {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 5 on drive 1, Play 6 on drive 2, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Bob Christian', 'pfr_id': 'ChriBo00'}
# Play 7 on drive 2, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Willie Green', 'pfr_id': 'GreeWi00'}
# Play 8 on drive 2, Penalty by {'name': 'Derrick Graham', 'pfr_id': 'GrahDe21'}
# Play 9 on drive 2, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Mark Carrier', 'pfr_id': 'CarrMa00'}
# Play 10 on drive 2, Play 11 on drive 2, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Mark Carrier', 'pfr_id': 'CarrMa00'}
# Play 12 on drive 2, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 13 on drive 2, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 14 on drive 2, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Pete Metzelaars', 'pfr_id': 'MetzPe00'}
# Play 15 on drive 2, Play 16 on drive 3, Kickoff by {'name': 'John Kasay', 'pfr_id': 'kasayjoh01'}
# 	return by {'name': 'Roell Preston', 'pfr_id': 'PresRo00'}
# Play 17 on drive 4, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 18 on drive 4, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 19 on drive 4, Incomplete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'}
# Play 20 on drive 4, Play 21 on drive 5, Kickoff by {'name': 'John Kasay', 'pfr_id': 'kasayjoh01'}
# 	return by {'name': 'Roell Preston', 'pfr_id': 'PresRo00'}
# Play 22 on drive 5, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 23 on drive 5, Play 24 on drive 5, Penalty by {'name': 'Mike Fox', 'pfr_id': 'FoxxMi20'}
# Play 25 on drive 5, Penalty by {'name': 'Mike Zandofsky', 'pfr_id': 'ZandMi20'}
# Play 26 on drive 5, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 27 on drive 5, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 28 on drive 5, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 29 on drive 5, Incomplete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00
pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'}
# Play 167 on drive 28, Play 168 on drive 28, Play 169 on drive 28, Play 170 on drive 29, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 171 on drive 29, Play 172 on drive 29, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 173 on drive 29, Play 174 on drive 29, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 175 on drive 29, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 176 on drive 29, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 177 on drive 29, Play 178 on drive 29, Play 179 on drive 29, Play 180 on drive 30, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Bob Christian', 'pfr_id': 'ChriBo00'}
# Play 181 on drive 30, Incomplete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'}
# Play 182 on drive 30, Incomplete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'}
# Play 183 on drive 30, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Willie Green', 'pfr_id': 'GreeWi00'}
# Play 184 on drive 30, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Willie Green', 'pfr_id': 'GreeWi00'}
# Play 185 on drive 30, Play 186 on drive 30, Penalty by {'name': 'Bob Christian', 'pfr_id': 'ChriBo00'}
# Play 187 on drive 30, Play 188 on drive 31, Kickoff by {'name': 'John Kasay', 'pfr_id': 'kasayjoh01'}
# 	return by {'name': 'Ron George', 'pfr_id': 'GeorRo20'}
# Play 189 on drive 31, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Bert Emanuel', 'pfr_id': 'EmanBe00'}
# Play 190 on drive 31, Incomplete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'}
# Play 191 on drive 31, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 192 on drive 31, Play 193 on drive 32, Kickoff by {'name': 'Morten Andersen', 'pfr_id': 'andermor01'}
# 	touchback
# Play 194 on drive 32, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 195 on drive 32, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Mark Carrier', 'pfr_id': 'CarrMa00'}
# Play 196 on drive 32, Complete pass by {'name': 'Frank Reich', 'pfr_id': 'ReicFr00'} on
# 	 to {'name': 'Howard Griffith', 'pfr_id': 'GrifHo00'}
# Play 197 on drive 32, Rush by {'name': 'Randy Baldwin', 'pfr_id': 'BaldRa00'}
# Play 198 on drive 32, Play 199 on drive 33, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 200 on drive 33, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 201 on drive 33, Complete pass by {'name': 'Jeff George', 'pfr_id': 'GeorJe00'} on
# 	 to {'name': 'Bert Emanuel', 'pfr_id': 'EmanBe00'}
# Play 202 on drive 33, Rush by {'name': 'Craig Heyward', 'pfr_id': 'HeywCr00'}
# Play 203 on drive 33, Rush by {'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'}
# Play 204 on drive 33,

# %%
df = pd.DataFrame(plays

# %%
df[df['drive']==1]
# Out:
#   Quarter Time remaining in this quarter Down ToGo Play location  \
# 0       1                          15:00                  CAR 30
# 1       1                                   1   10        ATL 23
# 2       1                                   2    7        ATL 26
# 3       1                                   3    1        ATL 32
# 4       1                                   4    1        ATL 32
#
#                                     Play description Away Points Home Points  \
# 0  John Kasay kicks off 66 yards, returned by Roe...           0           0
# 1  Craig Heyward middle for 3 yards (tackle by Ro...           0           0
# 2  Jeff George pass complete left for 6 yards (ta...           0           0
# 3  Eric Metcalf pass incomplete right intended fo...           0           0
# 4  Dan Stryzinski punts 43 yards, returned by Eri...           0           0
#
#   Expected points before this play, based on down, distance, and field position  \
# 0                                              0.000
# 1                                              0.480
# 2                                              0.340
# 3                                              0.430
# 4                                             -1.240
#
#   Expected points after this play (or actual scoring results of the play if it was a score)  \
# 0                                              0.480
# 1                                              0.340
# 2                                              0.430
# 3                                             -1.240
# 4                                             -1.270
#
#    drive  score                                     action_players
# 0      1  False  [{'name': 'John Kasay', 'pfr_id': 'kasayjoh01'...
# 1      1  False  [{'name': 'Craig Heyward', 'pfr_id': 'HeywCr00...
# 2      1  False  [{'name': 'Jeff George', 'pfr_id': 'GeorJe00'}...
# 3      1  False  [{'name': 'Eric Metcalf', 'pfr_id': 'MetcEr00'...
# 4      1  False  [{'name': 'Dan Stryzinski', 'pfr_id': 'StryDa2...

# %%
df
# Out:
#     quarter Quarter Time remaining in this quarter Down    ToGo  \
# 0         1   15:00                                      CAR 30
# 1         1                                      1   10  ATL 23
# 2         1                                      2    7  ATL 26
# 3         1                                      3    1  ATL 32
# 4         1                                      4    1  ATL 32
# ..      ...     ...                            ...  ...     ...
# 199      OT                                      2    8  CAR 29
# 200      OT                                      3    4  CAR 25
# 201      OT                                      1   10  CAR 20
# 202      OT                                      2    8  CAR 18
# 203      OT                                      3    6  CAR 16
#
#                                          Play location Play description  \
# 0    John Kasay kicks off 66 yards, returned by Roe...                0
# 1    Craig Heyward middle for 3 yards (tackle by Ro...                0
# 2    Jeff George pass complete left for 6 yards (ta...                0
# 3    Eric Metcalf pass incomplete right intended fo...                0
# 4    Dan Stryzinski punts 43 yards, returned by Eri...                0
# ..                                                 ...              ...
# 199  Jeff George pass complete right to Eric Metcal...               20
# 200  Jeff George pass complete right to Bert Emanue...               20
# 201  Craig Heyward middle for 2 yards (tackle by La...               20
# 202  Eric Metcalf left for 2 yards (tackle by Geral...               20
# 203            Morten Andersen 35 yard field goal good               20
#
#     Away Points Home Points  \
# 0             0       0.000
# 1             0       0.480
# 2             0       0.340
# 3             0       0.430
# 4             0      -1.240
# ..          ...         ...
# 199          20       3.240
# 200          20       3.070
# 201          20       4.240
# 202          20       3.960
# 203          23       3.520
#
#     Expected points before this play, based on down, distance, and field position  \
# 0                                                0.480
# 1                                                0.340
# 2                                                0.430
# 3                                               -1.240
# 4                                               -1.270
# ..                                                 ...
# 199                                              3.070
# 200                                              4.240
# 201                                              3.960
# 202                                              3.520
# 203                                              3.000
#
#      drive  score
# 0        1  False
# 1        1  False
# 2        1  False
# 3        1  False
# 4        1  False
# ..     ...    ...
# 199     33  False
# 200     33  False
# 201     33  False
# 202     33  False
# 203     33   True
#
# [204 rows x 12 columns]
